# %% [markdown]
# #Extracting Shapefiles from a Zip Virtual File Server in Fiona.

# %% [markdown]
# In this notebook we will:
# - open a Zip file in-memory
# - extract each of the underlying shapefiles
# - convert them to Fiona objects
# - and then plot them.

# %% [markdown]
# ## Extracting a Shapefile from an in-memory folder

# %% [markdown]
# Let's try Fiona's virtual file system feature as described [here](http://toblerity.org/fiona/README.html#collections-from-archives-and-virtual-file-systems).

# %%
import fiona
import os
from zipfile import ZipFile

assets = '/'.join(os.getcwd().split('/')[:-1] + ['assets'])
zipfile = assets + '/shapefiles.zip'

# %%
with fiona.drivers():

    for i, layername in enumerate(
            fiona.listlayers(
                '/shapefiles',
                vfs='zip://'+zipfile)):
        with fiona.open(
                '/shapefiles',
                vfs='zip://'+zipfile,
                layer=i) as c:
            print(i, layername, len(c))
# Out:
# (0, u'RoadAsphalt', 2)
# (1, u'DitchLine', 40)
# (2, u'WaterPipe', 33)
# (3, u'boundary', 6)
# (4, u'TreeLine', 6)
# (5, u'NaturalGas', 53)
# (6, u'RoadConcrete', 4)
# (7, u'wetlands1', 26258)
# (8, u'RoadDriveway', 169)
# (9, u'PowerLine', 6)
# (10, u'ProposedAccessRoads', 47)
# (11, u'Fence', 164)
# (12, u'turbines', 49)
# (13, u'wetlands2', 32423)
# (14, u'RoadGravel', 18)

# %% [markdown]
# Beautiful. Now, let's fetch the 'Fence' layer and plot it using Folium into a Leaflet map. First, let's see what is the CRS of our layers.

# %%
#Check CRS 
with fiona.drivers():
    with fiona.open(
        '/shapefiles',
        vfs = 'zip://' + zipfile,
        layer = 'Fence') as layer:
        print 'CRS:', layer.crs
# Out:
# CRS: {u'lon_0': -93.5, u'datum': u'NAD83', u'y_0': 0, u'no_defs': True, u'proj': u'lcc', u'x_0': 500000.0000000002, u'units': u'us-ft', u'lat_2': 41.78333333333333, u'lat_1': 40.61666666666667, u'lat_0': 40}

# %% [markdown]
# Now, we want to convert this to WGS84 coordinate system to make it easier for Folium to plot. I'll take some code from the WindOps [repository](https://github.com/huevosabio/windopt/blob/master/app/windscripts/features.py) and adapt it to this specific case.

# %%
import pyproj

def pointTrans(crs,inverse=False):
    proj = pyproj.Proj(crs,preserve_units=True)
    def trans(tpl):
        return proj(tpl[0],tpl[1],inverse=inverse)
    return trans

def customTransform(crs,original,toLatLon=False):
    '''
    Transorms from custom projection to lat,lon
    and viceversa
    crs is a dictionary, original is a geojson-like dict,
    toLatLon: if true will transform to LatLon, otherwise from
    '''
    geometry = original.copy()
    trans = pointTrans(crs,inverse=toLatLon)
    if geometry['type'] == 'Point':
        geometry['coordinates'] = trans(geometry['coordinates'])
    elif geometry['type'] == 'MultiPoint' or geometry['type'] == 'LineString':
        geometry['coordinates'] = map(trans,geometry['coordinates'])
    elif geometry['type'] == 'Polygon' or geometry['type'] == 'MultiLineString':
        elements = []
        for element in geometry['coordinates']:
            elements.append(map(trans,element))
        geometry['coordinates'] = elements
    elif geometry['type'] == 'MultiPolygon':
        elements = []
        for element in geometry['coordinates']:
            subelements = []
            for subelement in element:
                subelements.append(map(trans,subelement))
            elements.append(map(trans, element))
        geometry['coordinates'] = elements
    else:
        raise NameError("Geometry type not supported: " + geometry['type'])
        return
    return geometry


def get_geojson_from_shapefile(layername,zipfile):
    features = []
    with fiona.drivers():
        with fiona.open(
        '/shapefiles',
        vfs = 'zip://' + zipfile,
        layer = layername) as shp:
            crs = shp.crs
            proj = pyproj.Proj(crs)
            for feat in shp:
                feature = feat.copy()
                if not proj.is_latlong():
                    feature['geometry'] = customTransform(shp.crs,feature['geometry'],toLatLon=True)
                features.append(feature)
        geojson = {"type": "FeatureCollection","features": features}
    return geojson

# %%
fences = get_geojson_from_shapefile('Fence',zipfile)

# %% [markdown]
# We now have the 'Fence' as a GeoJson-like Python dictionary in WGS84 projection. Let's add it to a folium map.

# %%
import folium
import json

map_terrain = folium.Map(location=[41.12,-94.11], zoom_start=11)

# %%
map_terrain.geo_json(geo_str = json.dumps(fences))

# %%
map_terrain
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot; charset=&quot;utf-8&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/queue-async/1.0.7/queue.min.js&quot;></script>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       .legend {
#           padding: 0px 0px;
#           font: 10px sans-serif;
#           background: white;
#           background: rgba(255,255,255,0.8);
#           box-shadow: 0 0 15px rgba(0,0,0,0.2);
#           border-radius: 5px;
#       }
#
#       .key path {
#         display: none;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div id=&quot;map&quot; style=&quot;width: 100%; height: 100%&quot;></div>
#
#    <script>
#
#       queue()
#           .defer(function(callback){callback(null, JSON.parse('{&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.1465161589086, 41.22963861339252], [-94.1464568973631, 41.232030982244304], [-94.14648407432618, 41.23574928270452], [-94.14651622945696, 41.23666193389988]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.14648008254629, 41.23672648671988], [-94.14637195979601, 41.23672275113114]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.16596927901354, 41.243501287162196], [-94.16598809371757, 41.24143644330712], [-94.1659958444152, 41.24085158276262], [-94.16600159799992, 41.24011359175255], [-94.16604871242363, 41.23681334623477], [-94.1662508365271, 41.23668161106924], [-94.16828538667427, 41.23665554029297], [-94.17073277202982, 41.23665935317107], [-94.17078423045756, 41.23660068972543], [-94.17078504508713, 41.23659856879774]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.14646758251891, 41.22958506188538], [-94.14456141427802, 41.229558805695426], [-94.14188261989932, 41.229494278984916], [-94.14059971117375, 41.22948313922484]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.14016729185313, 41.22946825089767], [-94.13963094013413, 41.229444809032], [-94.1364254166907, 41.22931117494818], [-94.13395819766032, 41.22923272986079]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.13290695177953, 41.229210529701376], [-94.1323521468042, 41.2291953867676]]}, &quot;type&quot;: &quot;Feature&quot;, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;LAYER&quot;: &quot;C_FENC_EXST&quot;, &quot;GM_TYPE&quot;: &quot;Unknown Line Type&quot;, &quot;LINE_STYLE&quot;: &quot;Solid&quot;, &quot;LINE_COLOR&quot;: &quot;RGB(255,255,255)&quot;, &quot;LINE_WIDTH&quot;: 1, &quot;ELEVATION&quot;: null}}, {&quot;geometry&quot;: {&quot;type&quot;: &quot;LineString&quot;, &quot;coordinates&quot;: [[-94.13001708844222, 41.22896065161511], [-94.13180336315283, 41.22899 ...

# %% [markdown]
# Excellent, we can see the fences around Macksburg.
